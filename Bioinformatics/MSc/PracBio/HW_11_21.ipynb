# %%
# Install necessary packages
# !pip install gdown plotly pandas

# Download the files using gdown
import gdown

files = {
    '12DyJHUHu2RjduOolcW6L-GRTC3BQYRpZ': 'biengi.bed',
    '12NS-FTtRFM32j1POjFEe0AH7i6Ze_RRI': 'biengi.bim',
    '12HmHDSoAslpQZ-REJnqLS4odML_-rfEu': 'biengi.pedind',
    '12DbtxNZCEvdOzyxHVyrVKRLZMFKNh97f': 'biengi.fam'
}

for file_id, file_name in files.items():
    gdown.download(f'https://drive.google.com/uc?id={file_id}', file_name, quiet=False)
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (5.2.0)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (5.24.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.16.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.66.6)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly) (9.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly) (24.2)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2024.8.30)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)
# Downloading...
# From: https://drive.google.com/uc?id=12DyJHUHu2RjduOolcW6L-GRTC3BQYRpZ
# To: /content/biengi.bed
# 100%|██████████| 54.2M/54.2M [00:02<00:00, 19.5MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=12NS-FTtRFM32j1POjFEe0AH7i6Ze_RRI
# To: /content/biengi.bim
# 100%|██████████| 6.70M/6.70M [00:00<00:00, 80.9MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=12HmHDSoAslpQZ-REJnqLS4odML_-rfEu
# To: /content/biengi.pedind
# 100%|██████████| 42.0k/42.0k [00:00<00:00, 50.2MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=12DbtxNZCEvdOzyxHVyrVKRLZMFKNh97f
# To: /content/biengi.fam
# 100%|██████████| 38.0k/38.0k [00:00<00:00, 49.5MB/s]

# %%
# !wget https://s3.amazonaws.com/plink1-assets/plink_linux_x86_64_20231211.zip
# Out:
# --2024-11-24 16:36:19--  https://s3.amazonaws.com/plink1-assets/plink_linux_x86_64_20231211.zip
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.217.46.158, 52.216.219.8, 52.216.12.38, ...
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.217.46.158|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8953953 (8.5M) [application/zip]
# Saving to: ‘plink_linux_x86_64_20231211.zip.1’
#
# plink_linux_x86_64_ 100%[===================>]   8.54M  4.53MB/s    in 1.9s
#
# 2024-11-24 16:36:22 (4.53 MB/s) - ‘plink_linux_x86_64_20231211.zip.1’ saved [8953953/8953953]

# %%
# !unzip plink_linux_x86_64_20231211.zip
# Out:
# Archive:  plink_linux_x86_64_20231211.zip
#   inflating: plink
# replace LICENSE? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: LICENSE
#   inflating: toy.ped
#   inflating: toy.map
#   inflating: prettify

# %%
# !chmod +x plink

# %%
# !mv plink /usr/local/bin/

# %%
# !plink --version
# Out:
# PLINK v1.90b7.2 64-bit (11 Dec 2023)

# %%
# Run PLINK PCA analysis
# !plink --bfile biengi --pca --out biengi_pca
# Out:
# PLINK v1.90b7.2 64-bit (11 Dec 2023)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to biengi_pca.log.
# Options in effect:
#   --bfile biengi
#   --out biengi_pca
#   --pca
#
# 12978 MB RAM detected; reserving 6489 MB for main workspace.
# 242180 variants loaded from .bim file.
# 894 people (574 males, 320 females) loaded from .fam.
# Using up to 2 threads (change this with --threads).
# Before main variant filters, 894 founders and 0 nonfounders present.
#  done.
# Total genotyping rate is 0.999006.
# 242180 variants and 894 people pass filters and QC.
# Note: No phenotypes present.
# Relationship matrix calculation complete.
# --pca: Results saved to biengi_pca.eigenval and biengi_pca.eigenvec .

# %%
import pandas as pd

# Load PCA eigenvectors
pca_data = pd.read_csv('biengi_pca.eigenvec', delim_whitespace=True, header=None)
pca_data.columns = ['FID', 'IID'] + [f'PC{i}' for i in range(1, pca_data.shape[1] - 1)]

# Display the first few rows
pca_data.head()
# Out:
# <ipython-input-8-ed508b78036e>:4: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   pca_data = pd.read_csv('biengi_pca.eigenvec', delim_whitespace=True, header=None)
#                  FID                IID       PC1       PC2       PC3  \
# 0  4461875510_R01C01  4461875510_R01C01  0.022805  0.046644  0.025682
# 1  4461875510_R01C02  4461875510_R01C02  0.029046  0.031433  0.032579
# 2  4461875510_R02C01  4461875510_R02C01  0.025890  0.043415  0.024259
# 3  4461875513_R02C02  4461875513_R02C02  0.022355  0.045329  0.024989
# 4  4461875513_R01C02  4461875513_R01C02  0.024226  0.043572  0.015883
#
#         PC4       PC5       PC6       PC7       PC8  ...      PC11      PC12  \
# 0 -0.009200 -0.003159 -0.009250  0.004704 -0.003999  ...  0.031829 -0.024709
# 1 -0.015769 -0.002586 -0.024625  0.003845 -0.007098  ... -0.021524  0.001733
# 2 -0.010237 -0.005302 -0.018654  0.014151 -0.010939  ...  0.042643 -0.042631
# 3 -0.014831 -0.008035  0.001440  0.027770 -0.023837  ...  0.038537 -0.021936
# 4 -0.009853 -0.004136 -0.011679  0.010524 -0.010580  ...  0.044584 -0.037172
#
#        PC13      PC14      PC15      PC16      PC17      PC18      PC19  \
# 0 -0.043020  0.049520  0.081407  0.054900  0.031768 -0.037673 -0.043701
# 1 -0.025462 -0.005282  0.023335  0.009862 -0.035812  0.000900  0.003050
# 2 -0.014694  0.050725  0.074761  0.093167  0.024564  0.008311 -0.047672
# 3  0.001573  0.052039  0.107735  0.090628  0.001787 -0.048874 -0.061143
# 4 -0.037817  0.047730  0.075309  0.111941 -0.006808 -0.028436 -0.023186
#
#        PC20
# 0  0.016445
# 1  0.012582
# 2  0.038053
# 3 -0.003882
# 4  0.053598
#
# [5 rows x 22 columns]

# %%
import plotly.express as px

# Create an interactive scatter plot
fig = px.scatter(
    pca_data,
    x='PC1',
    y='PC2',
    color='FID',
    hover_data=['IID'],
    title='PCA: PC1 vs PC2'
)

# Show the interactive plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0a0bffde-55d6-433c-bc6f-b69993d584be" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0a0bffde-55d6-433c-bc6f-b69993d584be")) {                    Plotly.newPlot(                        "0a0bffde-55d6-433c-bc6f-b69993d584be",                        [{"customdata":[["4461875510_R01C01"]],"hovertemplate":"FID=4461875510_R01C01\u003cbr\u003ePC1=%{x}\u003cbr\u003ePC2=%{y}\u003cbr\u003eIID=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"4461875510_R01C01","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"4461875510_R01C01","orientation":"v","showlegend":true,"x":[0.0228054],"xaxis":"x","y":[0.0466437],"yaxis":"y","type":"scatter"},{"customdata":[["4461875510_R01C02"]],"hovertemplate":"FID=4461875510_R01C02\u003cbr\u003ePC1=%{x}\u003cbr\u003ePC2=%{y}\u003cbr\u003eIID=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"4461875510_R01C02","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"4461875510_R01C02","orientation":"v","showlegend":true,"x":[0.0290457],"xaxis":"x","y":[0.0314334],"yaxis":"y","type":"scatter"},{"customdata":[["4461875510_R02C01"]],"hovertemplate":"FID=4461875510_R02C01\u003cbr\u003ePC1=%{x}\u003cbr\u003ePC2=%{y}\u003cbr\u003eIID=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"4461875510_R02C01","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"4461875510_R02C01","orientation":"v","showlegend":true,"x":[0.0258902],"xaxis":"x","y":[0.0434145],"yaxis":"y","type":"scatter"},{"customdata":[["4461875513_R02C02"]],"hovertemplate":"FID=4461875513_R02C02\u003cbr\u003ePC1=%{x}\u003cbr\u003ePC2=%{y}\u003cbr\u003eIID=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"4461875513_R02C02","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"4461875513_R02C02","orientation":"v","showlegend":true,"x":[0.022355],"xaxis":"x","y":[0.0453286],"yaxis":"y","type":"scatter"},{"customdata":[["4461875513_R01C02"]],"hovertemplate":"FID=4461875513_R01C02\u003cbr\u003ePC1=%{x}\u003cbr\u003ePC2=%{y}\u003cbr\u003eIID=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"4461875513_R01C02","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"4461875513_R01C02","orientation":"v","showlegend":true,"x":[0.0242264],"xaxis":"x","y":[0.0435723],"yaxis":"y","type":"scatter"},{"customdata":[["4461875593_R01C02"]],"hovertemplate":"FID=4461875593_R01C02\u003cbr\u003ePC1=%{x}\u003cbr\u003ePC2=%{y}\u003cbr\u003eIID=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"4461875593_R01C02","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"4461875593_R01C02","orientation":"v","showlegend":true,"x":[0.0227747],"xaxis":"x","y":[0.0471251],"yaxis":"y","type":"scatter"},{"customdata":[["4461875593_R02C01"]],"hovertemplate":"FID=4461875593_R02C01\u003cbr\u003ePC1=%{x}\u003cbr\u003ePC2=%{y}\u003cbr\u003eIID=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"4461875593_R02C01","marker":{"color":"#FF6692","symbol":"circle"},"mode":"markers","name":"4461875593_R02C01","orientation":"v","showlegend":true,"x":[0.0243208],"xaxis":"x","y":[0.0449372],"yaxis":"y","type":"scatter"},{"customdata":[["4461875593_R02C02"]],"hovertemplate":"FID=4461875593_R02C02\u003cbr\u003ePC1=%{x}\u003cbr\u003ePC2=%{y}\u003cbr\u003eIID=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"4461875593_R02C02","marker":{"color":"#B6E880","symbol":"circle"},"mode":"markers","name":"4461875593_R02C02","orientation":"v","showlegend":true,"x":[0.0294774],"xaxis":"x","y":[0.0353663],"yaxis":"y","type": ...

# %%
# Download and install Admixture
# !wget https://dalexander.github.io/admixture/binaries/admixture_linux-1.3.0.tar.gz
# !tar -xvzf admixture_linux-1.3.0.tar.gz

# Navigate to the extracted directory and move the admixture binary
# !chmod +x dist/admixture_linux-1.3.0/admixture
# !mv dist/admixture_linux-1.3.0/admixture /usr/local/bin/

# Verify installation
# !admixture --version
# Out:
# --2024-11-24 16:37:57--  https://dalexander.github.io/admixture/binaries/admixture_linux-1.3.0.tar.gz
# Resolving dalexander.github.io (dalexander.github.io)... 185.199.108.153, 185.199.109.153, 185.199.110.153, ...
# Connecting to dalexander.github.io (dalexander.github.io)|185.199.108.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1916705 (1.8M) [application/gzip]
# Saving to: ‘admixture_linux-1.3.0.tar.gz.1’
#
# admixture_linux-1.3 100%[===================>]   1.83M  5.93MB/s    in 0.3s
#
# 2024-11-24 16:37:58 (5.93 MB/s) - ‘admixture_linux-1.3.0.tar.gz.1’ saved [1916705/1916705]
#
# dist/admixture_linux-1.3.0/
# dist/admixture_linux-1.3.0/README.32.txt
# dist/admixture_linux-1.3.0/admixture
# dist/admixture_linux-1.3.0/admixture32
# dist/admixture_linux-1.3.0/admixture-manual.pdf
# ****                   ADMIXTURE Version 1.3.0                  ****
# ****                    Copyright 2008-2015                     ****
# ****           David Alexander, Suyash Shringarpure,            ****
# ****                John  Novembre, Ken Lange                   ****
# ****                                                            ****
# ****                 Please cite our paper!                     ****
# ****   Information at www.genetics.ucla.edu/software/admixture  ****
#
# 1.3.0

# %%
import time
from google.colab import files

K_values = [5, 4]
for K in K_values:
    start_time = time.time()  # Record the start time
    print(f"Running ADMIXTURE for K = {K}...")

    # Run the admixture command
    # !admixture --cv biengi.bed {K}

    elapsed_time = time.time() - start_time  # Calculate elapsed time
    print(f"Completed ADMIXTURE for K = {K} in {elapsed_time:.2f} seconds.")

    # Download the resulting files
    files.download(f'biengi.{K}.Q')
    files.download(f'biengi.{K}.P')
# Out:
# Running ADMIXTURE for K = 5...
# ****                   ADMIXTURE Version 1.3.0                  ****
# ****                    Copyright 2008-2015                     ****
# ****           David Alexander, Suyash Shringarpure,            ****
# ****                John  Novembre, Ken Lange                   ****
# ****                                                            ****
# ****                 Please cite our paper!                     ****
# ****   Information at www.genetics.ucla.edu/software/admixture  ****
#
# Cross-validation will be performed.  Folds=5.
# Random seed: 43
# Point estimation method: Block relaxation algorithm
# Convergence acceleration algorithm: QuasiNewton, 3 secant conditions
# Point estimation will terminate when objective function delta < 0.0001
# Estimation of standard errors disabled; will compute point estimates only.
# Size of G: 894x242180
# Performing five EM steps to prime main algorithm
# 1 (EM) 	Elapsed: 37.148	Loglikelihood: -2.41289e+08	(delta): 8.79154e+07
# 2 (EM) 	Elapsed: 37.779	Loglikelihood: -2.3553e+08	(delta): 5.75942e+06
# 3 (EM) 	Elapsed: 36.454	Loglikelihood: -2.339e+08	(delta): 1.6297e+06
# 4 (EM) 	Elapsed: 37.078	Loglikelihood: -2.32918e+08	(delta): 982057
# 5 (EM) 	Elapsed: 37.115	Loglikelihood: -2.32218e+08	(delta): 700544
# Initial loglikelihood: -2.32218e+08
# Starting main algorithm
# 1 (QN/Block) 	Elapsed: 96.982	Loglikelihood: -2.25411e+08	(delta): 6.80619e+06
# 2 (QN/Block) 	Elapsed: 97.74	Loglikelihood: -2.24473e+08	(delta): 938556
# 3 (QN/Block) 	Elapsed: 104.354	Loglikelihood: -2.24195e+08	(delta): 277940
# 4 (QN/Block) 	Elapsed: 107.612	Loglikelihood: -2.2408e+08	(delta): 114794
# 5 (QN/Block) 	Elapsed: 107.907	Loglikelihood: -2.24045e+08	(delta): 34694.2
# 6 (QN/Block) 	Elapsed: 104.242	Loglikelihood: -2.24021e+08	(delta): 23993.2
# 7 (QN/Block) 	Elapsed: 108.297	Loglikelihood: -2.24003e+08	(delta): 18994.3
# 8 (QN/Block) 	Elapsed: 121.13	Loglikelihood: -2.23988e+08	(delta): 14390.9
# 9 (QN/Block) 	Elapsed: 113.881	Loglikelihood: -2.23979e+08	(delta): 8987.59
# 10 (QN/Block) 	Elapsed: 113.579	Loglikelihood: -2.23967e+08	(delta): 11976.8
# 11 (QN/Block) 	Elapsed: 114.532	Loglikelihood: -2.23959e+08	(delta): 8434.81
# 12 (QN/Block) 	Elapsed: 107.214	Loglikelihood: -2.23952e+08	(delta): 6893.01
# 13 (QN/Block) 	Elapsed: 112.151	Loglikelihood: -2.23948e+08	(delta): 3423.38
# 14 (QN/Block) 	Elapsed: 106.515	Loglikelihood: -2.23941e+08	(delta): 6946.61
# 15 (QN/Block) 	Elapsed: 103.835	Loglikelihood: -2.23937e+08	(delta): 4360.96
# 16 (QN/Block) 	Elapsed: 104.314	Loglikelihood: -2.23933e+08	(delta): 4331.68
# 17 (QN/Block) 	Elapsed: 106.847	Loglikelihood: -2.23931e+08	(delta): 1886.45
# 18 (QN/Block) 	Elapsed: 104.206	Loglikelihood: -2.2393e+08	(delta): 1280.7
# 19 (QN/Block) 	Elapsed: 103.837	Loglikelihood: -2.23928e+08	(delta): 1953.26
# 20 (QN/Block) 	Elapsed: 105.186	Loglikelihood: -2.23927e+08	(delta): 1030.78
# 21 (QN/Block) 	Elapsed: 103.735	Loglikelihood: -2.23926e+08	(delta): 542.62
# 22 (QN/Block) 	Elapsed: 108.798	Loglikelihood: -2.23926e+08	(delta): 412.391
# 23 (QN/Block) 	Elapsed: 107.922	Loglikelihood: -2.23925e+08	(delta): 494.633
# 24 (QN/Block) 	Elapsed: 111.255	Loglikelihood: -2.23925e+08	(delta): 293.008
# 25 (QN/Block) 	Elapsed: 108.832	Loglikelihood: -2.23925e+08	(delta): 286.151
# 26 (QN/Block) 	Elapsed: 104.799	Loglikelihood: -2.23924e+08	(delta): 172.947
# 27 (QN/Block) 	Elapsed: 105.43	Loglikelihood: -2.23924e+08	(delta): 333.894
# 28 (QN/Block) 	Elapsed: 103.681	Loglikelihood: -2.23924e+08	(delta): 225.006
# 29 (QN/Block) 	Elapsed: 103.885	Loglikelihood: -2.23924e+08	(delta): 229.359
# 30 (QN/Block) 	Elapsed: 103.972	Loglikelihood: -2.23924e+08	(delta): 52.3001
# 31 (QN/Block) 	Elapsed: 103.428	Loglikelihood: -2.23923e+08	(delta): 149.592
# 32 (QN/Block) 	Elapsed: 103.744	Loglikelihood: -2.23923e+08	(delta): 111.616
# 33 (QN/Block) 	Elapsed: 103.77	Loglikelihood: -2.23923e+08	(delta): 115.306
# 34 (QN/Block) 	Elapsed: 103.207	Loglikelihood: -2.23923e+08	(delta): 35.3178
# 35 (QN/Block) 	Elapsed: 104.444	Loglikelihood: -2.23923e+08	(delta): 27.8526
# 36 (QN/Block) 	Elapsed: 103.766	Loglikelihood: -2.23923e+08	(delta): 9.62024
# 37 (QN/Block) 	Elapsed: 103.414	Loglikelihood: -2.23923e+08	(delta): 16.8303
# 38 (QN/Block) 	Elapsed: 104.197	Loglikelihood: -2.23923e+08	(delta): 16.9202
# 39 (QN/Block) 	Elapsed: 103.64	Loglikelihood: -2.23923e+08	(delta): 10.3882
# 40 (QN/Block) 	Elapsed: 103.55	Loglikelihood: -2.23923e+08	(delta): 2.854
# 41 (QN/Block) 	Elapsed: 103.979	Loglikelihood: -2.23923e+08	(delta): 13.8011
# 42 (QN/Block) 	Elapsed: 103.331	Loglikelihood: -2.23923e+08	(delta): 9.03911
# 43 (QN/Block) 	Elapsed: 103.571	Loglikelihood: -2.23923e+08	(delta): 4.07725
# 44 (QN/Block) 	Elapsed: 103.617	Loglikelihood: -2.23923e+08	(delta): 0.799008
# 45 (QN/Block) 	Elapsed: 103.431	Loglikelihood: -2.23923e+08	(delta): 2.70891
# 46 (QN/Block) 	Elapsed: 104.254	Loglikelihood: -2.23923e+08	(delta): 1.78802
# 47 (QN/Block) 	Elapsed: 103.412	Loglikelihood: -2.23923e+08	(delta): 1.13342
# 48 (QN/Block) 	Elapsed: 103.236	Loglikelihood: -2.23923e+08	(delta): -1.8027
# 49 (QN/Block) 	Elapsed: 103.882	Loglikelihood: -2.23923e+08	(delta): 1.85308
# 50 (QN/Block) 	Elapsed: 103.601	Loglikelihood: -2.23923e+08	(delta): 1.2222
# 51 (QN/Block) 	Elapsed: 113.736	Loglikelihood: -2.23923e+08	(delta): 0.0809435
# 52 (QN/Block) 	Elapsed: 104.689	Loglikelihood: -2.23923e+08	(delta): 0.230373
# 53 (QN/Block) 	Elapsed: 103.626	Loglikelihood: -2.23923e+08	(delta): 0.0694546
# 54 (QN/Block) 	Elapsed: 103.034	Loglikelihood: -2.23923e+08	(delta): 0.0995406
# 55 (QN/Block) 	Elapsed: 103.545	Loglikelihood: -2.23923e+08	(delta): 0.0305421
# 56 (QN/Block) 	Elapsed: 103.199	Loglikelihood: -2.23923e+08	(delta): 0.0272003
# 57 (QN/Block) 	Elapsed: 103.188	Loglikelihood: -2.23923e+08	(delta): 0.0202859
# 58 (QN/Block) 	Elapsed: 103.802	Loglikelihood: -2.23923e+08	(delta): 0.0203457
# 59 (QN/Block) 	Elapsed: 103.18	Loglikelihood: -2.23923e+08	(delta): 0.010155
# 60 (QN/Block) 	Elapsed: 103.392	Loglikelihood: -2.23923e+08	(delta): 0.0137617
# 61 (QN/Block) 	Elapsed: 103.652	Loglikelihood: -2.23923e+08	(delta): 0.00108206
# 62 (QN/Block) 	Elapsed: 103.044	Loglikelihood: -2.23923e+08	(delta): 0.000570685
# 63 (QN/Block) 	Elapsed: 104.064	Loglikelihood: -2.23923e+08	(delta): 0.000130415
# 64 (QN/Block) 	Elapsed: 105.39	Loglikelihood: -2.23923e+08	(delta): 0.000192314
# 65 (QN/Block) 	Elapsed: 105.34	Loglikelihood: -2.23923e+08	(delta): 0.000100285
# 66 (QN/Block) 	Elapsed: 105.162	Loglikelihood: -2.23923e+08	(delta): 6.02901e-05
# Summary:
# Converged in 66 iterations (7385.16 sec)
# Loglikelihood: -223923031.424040
# Fst divergences between estimated populations:
# 	Pop0	Pop1	Pop2	Pop3
# Pop0
# Pop1	0.073
# Pop2	0.097	0.060
# Pop3	0.028	0.074	0.099
# Pop4	0.103	0.059	0.066	0.099
# CV error (K=5): 0.56408
# Writing output files.
# Completed ADMIXTURE for K = 5 in 8895.83 seconds.
# Running ADMIXTURE for K = 4...
# ****                   ADMIXTURE Version 1.3.0                  ****
# ****                    Copyright 2008-2015                     ****
# ****           David Alexander, Suyash Shringarpure,            ****
# ****                John  Novembre, Ken Lange                   ****
# ****                                                            ****
# ****                 Please cite our paper!                     ****
# ****   Information at www.genetics.ucla.edu/software/admixture  ****
#
# Cross-validation will be performed.  Folds=5.
# Random seed: 43
# Point estimation method: Block relaxation algorithm
# Convergence acceleration algorithm: QuasiNewton, 3 secant conditions
# Point estimation will terminate when objective function delta < 0.0001
# Estimation of standard errors disabled; will compute point estimates only.
# Size of G: 894x242180
# Performing five EM steps to prime main algorithm
# 1 (EM) 	Elapsed: 38.076	Loglikelihood: -2.41608e+08	(delta): 9.46989e+07
# 2 (EM) 	Elapsed: 37.199	Loglikelihood: -2.35636e+08	(delta): 5.97195e+06
# 3 (EM) 	Elapsed: 36.992	Loglikelihood: -2.33817e+08	(delta): 1.81924e+06
# 4 (EM) 	Elapsed: 37.046	Loglikelihood: -2.32737e+08	(delta): 1.07932e+06
# 5 (EM) 	Elapsed: 37.042	Loglikelihood: -2.31996e+08	(delta): 741444
# Initial loglikelihood: -2.31996e+08
# Starting main algorithm
# 1 (QN/Block) 	Elapsed: 88.459	Loglikelihood: -2.2545e+08	(delta): 6.5461e+06
# 2 (QN/Block) 	Elapsed: 88.104	Loglikelihood: -2.24684e+08	(delta): 765818
# 3 (QN/Block) 	Elapsed: 99.014	Loglikelihood: -2.24453e+08	(delta): 230710
# 4 (QN/Block) 	Elapsed: 98.302	Loglikelihood: -2.24337e+08	(delta): 115863
# 5 (QN/Block) 	Elapsed: 98.149	Loglikelihood: -2.2432e+08	(delta): 17783.2
# 6 (QN/Block) 	Elapsed: 89.5	Loglikelihood: -2.24306e+08	(delta): 13634.1
# 7 (QN/Block) 	Elapsed: 89.604	Loglikelihood: -2.24296e+08	(delta): 10389.5
# 8 (QN/Block) 	Elapsed: 88.96	Loglikelihood: -2.24289e+08	(delta): 6527.35
# 9 (QN/Block) 	Elapsed: 88.639	Loglikelihood: -2.24284e+08	(delta): 4574.6
# 10 (QN/Block) 	Elapsed: 88.989	Loglikelihood: -2.2428e+08	(delta): 3987.64
# 11 (QN/Block) 	Elapsed: 90.024	Loglikelihood: -2.24277e+08	(delta): 3733.88
# 12 (QN/Block) 	Elapsed: 89.265	Loglikelihood: -2.2427e+08	(delta): 6266.03
# 13 (QN/Block) 	Elapsed: 92.787	Loglikelihood: -2.24269e+08	(delta): 1713.35
# 14 (QN/Block) 	Elapsed: 89.507	Loglikelihood: -2.24268e+08	(delta): 1043.06
# 15 (QN/Block) 	Elapsed: 88.928	Loglikelihood: -2.24267e+08	(delta): 868.524
# 16 (QN/Block) 	Elapsed: 88.565	Loglikelihood: -2.24266e+08	(delta): 561.846
# 17 (QN/Block) 	Elapsed: 88.936	Loglikelihood: -2.24266e+08	(delta): 539.524
# 18 (QN/Block) 	Elapsed: 89.72	Loglikelihood: -2.24265e+08	(delta): 312.393
# 19 (QN/Block) 	Elapsed: 89.551	Loglikelihood: -2.24265e+08	(delta): 468.726
# 20 (QN/Block) 	Elapsed: 88.992	Loglikelihood: -2.24265e+08	(delta): 308.979
# 21 (QN/Block) 	Elapsed: 91.822	Loglikelihood: -2.24264e+08	(delta): 252.07
# ^C
# Completed ADMIXTURE for K = 4 in 2257.77 seconds.
# ^C
# Completed ADMIXTURE for K = 4 in 2257.77 seconds.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

K_values = [3, 4, 5]
# Load and visualize Admixture results
for K in K_values:
    q_file = f"biengi.{K}.Q"
    admixture_data = pd.read_csv(q_file, delim_whitespace=True, header=None)

    # Add individual IDs for labeling
    admixture_data['IID'] = pca_data['IID']

    # Plot stacked bar chart
    fig, ax = plt.subplots(figsize=(10, 5))
    bottom_array = np.zeros(admixture_data.shape[0])
    for k in range(K):
        ax.bar(admixture_data.index, admixture_data[k], bottom=bottom_array, label=f'Cluster {k+1}')
        bottom_array += admixture_data[k]

    ax.set_title(f'Admixture Plot (K = {K})')
    ax.set_xlabel('Individuals')
    ax.set_ylabel('Admixture Proportion')
    ax.legend()
    plt.show()
# Out:
# <ipython-input-13-7ec24dacbb22>:9: FutureWarning:
#
# The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# <ipython-input-13-7ec24dacbb22>:9: FutureWarning:
#
# The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# <ipython-input-13-7ec24dacbb22>:9: FutureWarning:
#
# The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead

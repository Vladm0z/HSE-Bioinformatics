# %% [markdown]
# <a href="https://colab.research.google.com/github/Vladm0z/HSE-Bioinformatics/blob/main/Bioinformatics/MSc/PracBio/PracBio_0417.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # install some dependencies

# %%
! pip install biopython
# Out:
# Requirement already satisfied: biopython in /usr/local/lib/python3.11/dist-packages (1.85)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from biopython) (2.0.2)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from Bio import SeqIO
from scipy.spatial.distance import pdist
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster
from collections import Counter

# %% [markdown]
# #0. Load data

# %%
# https://github.com/rybinaanya/hse2025.git

# !git clone https://github.com/rybinaanya/hse2025.git
# Out:
# fatal: destination path 'hse2025' already exists and is not an empty directory.

# %%
# %cd hse2025
# Out:
# /content/hse2025

# %%
# !ls
# Out:
# accessory_binary_genes.fa	  h10_cog_barplot.pdf
# accessory_binary_genes.fa.newick  pan_genome_ref.emapper.annotations.tsv
# cheese_clusters.pdf		  pan_genome_reference.fa
# cluster_composition.pdf		  peptidase_barplot.pdf
# core_gene_alignment.aln		  README.md
# core_gene_alignment.tree	  summary_statistics.txt
# df_genbank_helvet.tsv		  swiss_enriched_gene_functions.csv
# gene_presence_absence.csv	  swiss_heatmap.pdf

# %% [markdown]
# **Description of files**
#
# `df_genbank_helvet.tsv`  =  metadata on lactobacillus strains
#
# `pan_genome_ref.emapper.annotations.tsv` = functional annotation of the genes from the `pan_genome_reference.fa` obtained by EggNog mapper (online web service)
#
# other fiels are part of the `Roary` output. `Roary` is a tool used for pangenome analysis https://sanger-pathogens.github.io/Roary/
#
#
# first, genomes of lactobacillus were annotated using `Prokka`:
# ```
# prokka --outdir ${out_dir} --prefix ${name} --force --locustag ${name[:20]} --cpus 4 ${fna_path}
# ```
#
# then, resulting GFF3 files were directed to Roary for pangenome analysis:
# ```
# roary -e -n -v prokka_output/*/*.gff -f roary_output
# ```

# %%
import pandas as pd

# Load files
# output of roary
gpa = pd.read_csv("gene_presence_absence.csv", low_memory=False)

#metadata for genomes
meta = pd.read_csv("df_genbank_helvet.tsv", sep="\t")

# functional annotation via EggNog for genomic sequences derived from Roary
eggnog = pd.read_csv("pan_genome_ref.emapper.annotations.tsv", sep='\t', comment='#', header=None)

# %%
column_names = [
    "query_name", "seed_eggNOG_ortholog", "evalue", "score", "eggNOG_taxonomy",
    "COG_OGs", "COG_category", "Description", "Preferred_name", "GOs",
    "EC", "KEGG_ko", "KEGG_Pathway", "KEGG_Module", "KEGG_Reaction",
    "KEGG_rclass", "BRITE", "KEGG_TC", "CAZy", "BiGG_Reaction", "Extra"
]

# Assign columns and extract key fields
eggnog.columns = column_names
eggnog.head()
# Out:
#                    query_name seed_eggNOG_ortholog         evalue   score  \
# 0  Lactobacillus_helvet_00001      326425.lhe_0001   0.000000e+00   899.0
# 1  Lactobacillus_helvet_00002      326425.lhe_0002  4.300000e-256   704.0
# 2  Lactobacillus_helvet_00003      405566.lhv_0003   6.150000e-47   150.0
# 3  Lactobacillus_helvet_00004      326425.lhe_0004  2.550000e-268   734.0
# 4  Lactobacillus_helvet_00005      326425.lhe_0005   0.000000e+00  1290.0
#
#                                      eggNOG_taxonomy        COG_OGs  \
# 0  COG0593@1|root,COG0593@2|Bacteria,1TPV7@1239|F...  91061|Bacilli
# 1  COG0592@1|root,COG0592@2|Bacteria,1TQ7J@1239|F...  91061|Bacilli
# 2  COG2501@1|root,COG2501@2|Bacteria,1VEJ2@1239|F...  91061|Bacilli
# 3  COG1195@1|root,COG1195@2|Bacteria,1TP9U@1239|F...  91061|Bacilli
# 4  COG0187@1|root,COG0187@2|Bacteria,1TQ0R@1239|F...  91061|Bacilli
#
#   COG_category                                        Description  \
# 0            L  it binds specifically double-stranded DNA at a...
# 1            L  Confers DNA tethering and processivity to DNA ...
# 2            S                             S4 domain protein YaaA
# 3            L  it is required for DNA replication and normal ...
# 4            L  A type II topoisomerase that negatively superc...
#
#   Preferred_name                                                GOs  ...  \
# 0           dnaA  GO:0003674,GO:0003676,GO:0003677,GO:0003688,GO...  ...
# 1           dnaN                                                  -  ...
# 2           yaaA                                                  -  ...
# 3           recF  GO:0000731,GO:0005575,GO:0005622,GO:0005623,GO...  ...
# 4           gyrB  GO:0003674,GO:0003824,GO:0003916,GO:0003918,GO...  ...
#
#      KEGG_ko                                       KEGG_Pathway KEGG_Module  \
# 0  ko:K02313                  ko02020,ko04112,map02020,map04112           -
# 1  ko:K02338  ko00230,ko00240,ko01100,ko03030,ko03430,ko0344...      M00260
# 2  ko:K14761                                                  -           -
# 3  ko:K03629                                   ko03440,map03440           -
# 4  ko:K02470                                                  -           -
#
#                  KEGG_Reaction KEGG_rclass  \
# 0                            -           -
# 1  R00375,R00376,R00377,R00378     RC02795
# 2                            -           -
# 3                            -           -
# 4                            -           -
#
#                                              BRITE KEGG_TC CAZy BiGG_Reaction  \
# 0                  ko00000,ko00001,ko03032,ko03036       -    -             -
# 1  ko00000,ko00001,ko00002,ko01000,ko03032,ko03400       -    -             -
# 2                                  ko00000,ko03009       -    -             -
# 3                          ko00000,ko00001,ko03400       -    -             -
# 4                  ko00000,ko01000,ko03032,ko03400       -    -             -
#
#                                            Extra
# 0                     Bac_DnaA,Bac_DnaA_C,DnaA_N
# 1  DNA_pol3_beta,DNA_pol3_beta_2,DNA_pol3_beta_3
# 2                                           S4_2
# 3                                          SMC_N
# 4     DNA_gyraseB,DNA_gyraseB_C,HATPase_c,Toprim
#
# [5 rows x 21 columns]

# %%
meta
# Out:
#        PMID Inferred Countries Cheese Associated               Cheese Type(s)  \
# 0  17993529                NaN               Yes                dairy, cheese
# 1  21398542              china               Yes         milk, fermented milk
# 2  23969047                NaN               Yes                 milk, cheese
# 3  30562882         tajikistan               Yes  milk, dairy, fermented milk
# 4  39366947                NaN               Yes         swiss cheese, cheese
# 5  39366947                NaN               Yes         swiss cheese, cheese
# 6  39366947                NaN               Yes         swiss cheese, cheese
# 7  39366947                NaN               Yes         swiss cheese, cheese
# 8  39366947                NaN               Yes         swiss cheese, cheese
#
#                                     Abstract Snippet         assembly  \
# 0  mobile genetic elements are major contributing...  GCA_000015385.1
# 1  lactobacillus helveticus strain h10 was isolat...  GCA_000189515.1
# 2  lactobacillus helveticus is a lactic acid bact...  GCA_000422165.1
# 3  the lactobacilli associated with a fermented g...  GCA_003545995.1
# 4  domestication - the artificial selection of wi...  GCA_043842675.1
# 5  domestication - the artificial selection of wi...  GCA_043842695.1
# 6  domestication - the artificial selection of wi...  GCA_043842715.1
# 7  domestication - the artificial selection of wi...  GCA_043842735.1
# 8  domestication - the artificial selection of wi...  GCA_043842745.1
#
#                        organism_name infraspecific_name  \
# 0  Lactobacillus helveticus DPC 4571    strain=DPC 4571
# 1       Lactobacillus helveticus H10         strain=H10
# 2    Lactobacillus helveticus CNRZ32      strain=CNRZ32
# 3           Lactobacillus helveticus       strain=TJA10
# 4           Lactobacillus helveticus     strain=Lh21462
# 5           Lactobacillus helveticus     strain=Lh21463
# 6           Lactobacillus helveticus     strain=Lh11961
# 7           Lactobacillus helveticus     strain=Lh11051
# 8           Lactobacillus helveticus     strain=Lh21456
#
#                                             ftp_path   taxid  species_taxid  \
# 0  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/0...  405566           1587
# 1  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/0...  767462           1587
# 2  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/0...  326425           1587
# 3  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/0...    1587           1587
# 4  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/0...    1587           1587
# 5  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/0...    1587           1587
# 6  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/0...    1587           1587
# 7  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/0...    1587           1587
# 8  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/0...    1587           1587
#
#                           short_name
# 0  Lactobacillus_helveticus_DPC_4571
# 1       Lactobacillus_helveticus_H10
# 2    Lactobacillus_helveticus_CNRZ32
# 3     Lactobacillus_helveticus_TJA10
# 4   Lactobacillus_helveticus_Lh21462
# 5   Lactobacillus_helveticus_Lh21463
# 6   Lactobacillus_helveticus_Lh11961
# 7   Lactobacillus_helveticus_Lh11051
# 8   Lactobacillus_helveticus_Lh21456

# %%
gpa.head()
# Out:
#          Gene Non-unique Gene name  \
# 0  group_1003                  NaN
# 1  group_1006                  NaN
# 2      pbpB_2                  NaN
# 3      gmuC_2                  NaN
# 4  group_1022                  NaN
#
#                                           Annotation  No. isolates  \
# 0                               hypothetical protein             9
# 1                               hypothetical protein             9
# 2                      Penicillin-binding protein 2B             9
# 3  PTS system oligo-beta-mannoside-specific EIIC ...             9
# 4                               hypothetical protein             9
#
#    No. sequences  Avg sequences per isolate  Genome Fragment  \
# 0              9                        1.0                1
# 1              9                        1.0                1
# 2              9                        1.0                1
# 3              9                        1.0                1
# 4              9                        1.0                1
#
#    Order within Fragment  Accessory Fragment  Accessory Order with Fragment  \
# 0                   3327                 NaN                            NaN
# 1                   3655                 NaN                            NaN
# 2                   1760                 NaN                            NaN
# 3                   1384                 NaN                            NaN
# 4                   1647                 NaN                            NaN
#
#    ... Avg group size nuc  Lactobacillus_helveticus_CNRZ32  \
# 0  ...                812       Lactobacillus_helvet_00792
# 1  ...                270       Lactobacillus_helvet_00891
# 2  ...                524       Lactobacillus_helvet_01065
# 3  ...                442       Lactobacillus_helvet_01147
# 4  ...               1633       Lactobacillus_helvet_01189
#
#        Lactobacillus_helveticus_DPC_4571  \
# 0   26b5ba34f29f7b4c2f09cf687f826e63_653
# 1   26b5ba34f29f7b4c2f09cf687f826e63_795
# 2   26b5ba34f29f7b4c2f09cf687f826e63_942
# 3  26b5ba34f29f7b4c2f09cf687f826e63_1026
# 4  26b5ba34f29f7b4c2f09cf687f826e63_1071
#
#             Lactobacillus_helveticus_H10  \
# 0  c8b8aac069fa36cfcc7e4f9a83d2e35b_1762
# 1  c8b8aac069fa36cfcc7e4f9a83d2e35b_1634
# 2  c8b8aac069fa36cfcc7e4f9a83d2e35b_1489
# 3  c8b8aac069fa36cfcc7e4f9a83d2e35b_1412
# 4  c8b8aac069fa36cfcc7e4f9a83d2e35b_1380
#
#         Lactobacillus_helveticus_Lh11051  \
# 0   806a6cbecdf33cd2f1bc8107b004e08b_910
# 1   806a6cbecdf33cd2f1bc8107b004e08b_334
# 2    806a6cbecdf33cd2f1bc8107b004e08b_58
# 3  806a6cbecdf33cd2f1bc8107b004e08b_1764
# 4   806a6cbecdf33cd2f1bc8107b004e08b_961
#
#         Lactobacillus_helveticus_Lh11961  \
# 0  1ee29166b31ca171df8a362c354bd71f_1532
# 1   1ee29166b31ca171df8a362c354bd71f_297
# 2   1ee29166b31ca171df8a362c354bd71f_237
# 3  1ee29166b31ca171df8a362c354bd71f_2190
# 4  1ee29166b31ca171df8a362c354bd71f_1843
#
#         Lactobacillus_helveticus_Lh21456  \
# 0  dff43c3e5b6cdf48961db087654b5209_1025
# 1   dff43c3e5b6cdf48961db087654b5209_338
# 2    dff43c3e5b6cdf48961db087654b5209_95
# 3  dff43c3e5b6cdf48961db087654b5209_1546
# 4   dff43c3e5b6cdf48961db087654b5209_981
#
#         Lactobacillus_helveticus_Lh21462  \
# 0    00ede7a30c146083dad2220567b409ca_12
# 1    00ede7a30c146083dad2220567b409ca_55
# 2   00ede7a30c146083dad2220567b409ca_776
# 3  00ede7a30c146083dad2220567b409ca_1230
# 4   00ede7a30c146083dad2220567b409ca_818
#
#         Lactobacillus_helveticus_Lh21463  \
# 0   36b5cfb678e09293c462c26eefc02c4c_961
# 1   36b5cfb678e09293c462c26eefc02c4c_352
# 2   36b5cfb678e09293c462c26eefc02c4c_121
# 3  36b5cfb678e09293c462c26eefc02c4c_1958
# 4   36b5cfb678e09293c462c26eefc02c4c_987
#
#           Lactobacillus_helveticus_TJA10
# 0   1c1750f3427ba223b09486cbadb269ba_831
# 1  1c1750f3427ba223b09486cbadb269ba_1523
# 2   1c1750f3427ba223b09486cbadb269ba_625
# 3   1c1750f3427ba223b09486cbadb269ba_290
# 4   1c1750f3427ba223b09486cbadb269ba_597
#
# [5 rows x 23 columns]

# %%
## Create mapping
# gene ID from eggNog table (same as record id in fasta file pan_genome_reference.fa)
# and gene ID in gene absence/presence table
# these gene IDs are different
# this is work around this situation

# Load FASTA
records = SeqIO.parse("pan_genome_reference.fa", "fasta")

# Map full ID (used in EggNOG) → group ID (used in Roary)
fasta_id_to_group = {
    record.id: record.description.split(' ')[-1]  # group_#### from group_####|strain|gene
    for record in records
}

# %%
# Extract group ID from query name to match with Roary gene names
eggnog['Gene'] = eggnog['query_name'].apply(lambda x: x.rstrip('_1')).map(fasta_id_to_group)
eggnog['COG_descr'] = eggnog['COG_category'] + ' | ' + eggnog.Description.apply(lambda x: x.split('.')[0])

# %%
# check new columns
eggnog.head()
# Out:
#                    query_name seed_eggNOG_ortholog         evalue   score  \
# 0  Lactobacillus_helvet_00001      326425.lhe_0001   0.000000e+00   899.0
# 1  Lactobacillus_helvet_00002      326425.lhe_0002  4.300000e-256   704.0
# 2  Lactobacillus_helvet_00003      405566.lhv_0003   6.150000e-47   150.0
# 3  Lactobacillus_helvet_00004      326425.lhe_0004  2.550000e-268   734.0
# 4  Lactobacillus_helvet_00005      326425.lhe_0005   0.000000e+00  1290.0
#
#                                      eggNOG_taxonomy        COG_OGs  \
# 0  COG0593@1|root,COG0593@2|Bacteria,1TPV7@1239|F...  91061|Bacilli
# 1  COG0592@1|root,COG0592@2|Bacteria,1TQ7J@1239|F...  91061|Bacilli
# 2  COG2501@1|root,COG2501@2|Bacteria,1VEJ2@1239|F...  91061|Bacilli
# 3  COG1195@1|root,COG1195@2|Bacteria,1TP9U@1239|F...  91061|Bacilli
# 4  COG0187@1|root,COG0187@2|Bacteria,1TQ0R@1239|F...  91061|Bacilli
#
#   COG_category                                        Description  \
# 0            L  it binds specifically double-stranded DNA at a...
# 1            L  Confers DNA tethering and processivity to DNA ...
# 2            S                             S4 domain protein YaaA
# 3            L  it is required for DNA replication and normal ...
# 4            L  A type II topoisomerase that negatively superc...
#
#   Preferred_name                                                GOs  ...  \
# 0           dnaA  GO:0003674,GO:0003676,GO:0003677,GO:0003688,GO...  ...
# 1           dnaN                                                  -  ...
# 2           yaaA                                                  -  ...
# 3           recF  GO:0000731,GO:0005575,GO:0005622,GO:0005623,GO...  ...
# 4           gyrB  GO:0003674,GO:0003824,GO:0003916,GO:0003918,GO...  ...
#
#   KEGG_Module                KEGG_Reaction KEGG_rclass  \
# 0           -                            -           -
# 1      M00260  R00375,R00376,R00377,R00378     RC02795
# 2           -                            -           -
# 3           -                            -           -
# 4           -                            -           -
#
#                                              BRITE KEGG_TC CAZy BiGG_Reaction  \
# 0                  ko00000,ko00001,ko03032,ko03036       -    -             -
# 1  ko00000,ko00001,ko00002,ko01000,ko03032,ko03400       -    -             -
# 2                                  ko00000,ko03009       -    -             -
# 3                          ko00000,ko00001,ko03400       -    -             -
# 4                  ko00000,ko01000,ko03032,ko03400       -    -             -
#
#                                            Extra        Gene  \
# 0                     Bac_DnaA,Bac_DnaA_C,DnaA_N         NaN
# 1  DNA_pol3_beta,DNA_pol3_beta_2,DNA_pol3_beta_3        dnaN
# 2                                           S4_2  group_4096
# 3                                          SMC_N        recF
# 4     DNA_gyraseB,DNA_gyraseB_C,HATPase_c,Toprim        gyrB
#
#                                            COG_descr
# 0  L | it binds specifically double-stranded DNA ...
# 1  L | Confers DNA tethering and processivity to ...
# 2                         S | S4 domain protein YaaA
# 3  L | it is required for DNA replication and nor...
# 4  L | A type II topoisomerase that negatively su...
#
# [5 rows x 23 columns]

# %% [markdown]
# # 1. Cluster strains by gene presence/absence

# %%
# Strain names in gene_presence_absence
strain_cols = [col for col in gpa.columns if col in meta['short_name'].values]

# Binary matrix: gene presence (1) or absence (0)
binary_matrix = gpa[strain_cols].notna().astype(int)

# %%
# from scipy.spatial.distance import pdist
# from scipy.cluster.hierarchy import linkage, dendrogram

# Transpose: we cluster strains, not genes
Z = linkage(pdist(binary_matrix.T, metric="hamming"), method="average")

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt

# Create mapping: strain → cheese color
cheese_colors = dict(zip(
    meta['short_name'],
    meta['Cheese Type(s)'].fillna("None")
))

# Assign colors
unique_types = list(set(cheese_colors.values()))
palette = sns.color_palette("Set2", len(unique_types))
color_map = {t: palette[i] for i, t in enumerate(unique_types)}
strain_colors = [color_map[cheese_colors[strain]] for strain in binary_matrix.columns]

# %%
# import matplotlib.patches as mpatches



plt.figure(figsize=(12, 6))
dendrogram(
    Z,
    labels=binary_matrix.columns,
    leaf_rotation=90,
    leaf_font_size=10,
    link_color_func=lambda k: 'black',  # black branches
)

# Color ticks or labels
ax = plt.gca()
xlabs = ax.get_xmajorticklabels()
for lbl in xlabs:
    strain = lbl.get_text()
    lbl.set_color(color_map[cheese_colors[strain]])

handles = [mpatches.Patch(color=color_map[k], label=k) for k in color_map]
plt.legend(handles=handles, bbox_to_anchor=(1.05, 1), loc='upper left')

plt.title("Strain Clustering by Gene Presence/Absence")
plt.tight_layout()
plt.savefig("cheese_clusters.pdf", bbox_inches='tight', format='pdf')
plt.show()

# %% [markdown]
# [Swiss Cheese Paper](https://pmc.ncbi.nlm.nih.gov/articles/PMC11452379/pdf/41467_2024_Article_52687.pdf)

# %%
# Identify strain columns
strain_cols = [col for col in gpa.columns if col.startswith("Lactobacillus") or col in gpa.columns[14:]]

# Binary matrix of gene presence (1) / absence (0)
binary_matrix = gpa[strain_cols].notna().astype(int)

# Count in how many genomes each gene is present
gene_counts = binary_matrix.sum(axis=1)

# Plot histogram
plt.figure(figsize=(8, 6))
plt.hist(gene_counts, bins=range(1, len(strain_cols)+2), edgecolor='k', alpha=0.6)
plt.xlabel("Number of genomes")
plt.ylabel("Number of genes")
plt.title("Gene Frequency Across Genomes")
plt.tight_layout()
plt.show()

# %% [markdown]
# # 2. H10 strain

# %%
# === Identify strain columns ===
strain_cols = [col for col in gpa.columns if col in meta['short_name'].values]
gene_matrix = gpa[strain_cols].notna().astype(int)

# === 1. Unique genes for H10 ===
h10_strain = meta[meta['short_name'].str.contains("H10", case=False, na=False)]['short_name'].values[0]
unique_h10_idx = (gene_matrix[h10_strain] == 1) & (gene_matrix.drop(columns=[h10_strain]).sum(axis=1) == 0)
unique_h10_genes = gpa.loc[unique_h10_idx, "Gene"].dropna().tolist()

# %%
len(unique_h10_genes)
# Out:
# 475

# %%
# select EggNog mapper annotation for genes soecific to H10 strain
eggnog_h10 = eggnog[eggnog.Gene.isin(unique_h10_genes)]

# %%
# Standard COG category descriptions (one-letter code: meaning)
cog_descriptions = {
    'J': 'Translation, ribosomal structure, and biogenesis',
    'A': 'RNA processing and modification',
    'K': 'Transcription',
    'L': 'Replication, recombination and repair',
    'B': 'Chromatin structure and dynamics',
    'D': 'Cell cycle control, cell division, chromosome partitioning',
    'Y': 'Nuclear structure',
    'V': 'Defense mechanisms',
    'T': 'Signal transduction mechanisms',
    'M': 'Cell wall/membrane/envelope biogenesis',
    'N': 'Cell motility',
    'Z': 'Cytoskeleton',
    'W': 'Extracellular structures',
    'U': 'Intracellular trafficking, secretion, and vesicular transport',
    'O': 'Post-translational modification, protein turnover, chaperones',
    'C': 'Energy production and conversion',
    'G': 'Carbohydrate transport and metabolism',
    'E': 'Amino acid transport and metabolism',
    'F': 'Nucleotide transport and metabolism',
    'H': 'Coenzyme transport and metabolism',
    'I': 'Lipid transport and metabolism',
    'P': 'Inorganic ion transport and metabolism',
    'Q': 'Secondary metabolites biosynthesis, transport and catabolism',
    'R': 'General function prediction only',
    'S': 'Function unknown'
}

# Expand multi-letter COG categories
cog_series = eggnog_h10['COG_category'].dropna().astype(str)
all_cogs = [c for cat in cog_series for c in cat if c in cog_descriptions]
cog_counts = Counter(all_cogs)

# Prepare data for plotting
labels = [f"{c} ({cog_descriptions[c]})" for c in cog_counts.keys()]
values = [cog_counts[c] for c in cog_counts]

# Plot
plt.figure(figsize=(12, 6))
plt.barh(labels, values)
plt.xlabel("Number of H10-unique genes")
plt.title("COG Functional Category Distribution")
plt.tight_layout()
plt.show()

# %%
#### QUICK SEARCH FOR CANDIDATE GENES RELATED TO FERMENTATION THAT ARE SPECIFIC TO THE H10 STRAIN ####

# Define keywords associated with milk fermentation functions
keywords = ['lactose', 'galactose', 'beta-galactosidase', 'peptidase', 'protease',
             'amino acid',
            'casein', 'dipeptidyl']

# Search for these keywords in the Description field
matches = eggnog_h10[eggnog_h10['Description'].str.contains('|'.join(keywords), case=False, na=False)]

# Select relevant columns for review
milk_ferment_related = matches[[
    'query_name', 'Preferred_name', 'Description', 'COG_category', 'KEGG_ko', 'KEGG_Pathway', 'GOs'
]]

# %%
milk_ferment_related
# Out:
#                                  query_name Preferred_name  \
# 2761   c8b8aac069fa36cfcc7e4f9a83d2e35b_524           prtB
# 2784   c8b8aac069fa36cfcc7e4f9a83d2e35b_622              -
# 2807   c8b8aac069fa36cfcc7e4f9a83d2e35b_720           lacZ
# 2822   c8b8aac069fa36cfcc7e4f9a83d2e35b_752           potE
# 2931  c8b8aac069fa36cfcc7e4f9a83d2e35b_1144           steT
# 2932  c8b8aac069fa36cfcc7e4f9a83d2e35b_1149           prtP
# 3089  c8b8aac069fa36cfcc7e4f9a83d2e35b_1946              -
# 3139  c8b8aac069fa36cfcc7e4f9a83d2e35b_2118          pepD4
#
#                                Description COG_category    KEGG_ko  \
# 2761    Belongs to the peptidase S8 family            O  ko:K01361
# 2784            Peptidase family M1 domain            M          -
# 2807                   -beta-galactosidase            G  ko:K12308
# 2822                            Amino Acid            E          -
# 2931                            amino acid            E  ko:K03294
# 2932    Belongs to the peptidase S8 family            O  ko:K01361
# 3089  Peptidase propeptide and YPEB domain            S          -
# 3139                           Dipeptidase            E  ko:K08659
#
#           KEGG_Pathway                                                GOs
# 2761                 -                                                  -
# 2784                 -                                                  -
# 2807  ko00052,map00052                                                  -
# 2822                 -                                                  -
# 2931                 -  GO:0003333,GO:0003674,GO:0005215,GO:0005342,GO...
# 2932                 -                                                  -
# 3089                 -                                                  -
# 3139                 -                                                  -

# %% [markdown]
# # 3. Quick check on genes encoding peptidases

# %%
# Build strain → cheese type mapping
cheese_map = dict(zip(meta['short_name'], meta['Cheese Type(s)']))

# Expand present_in_strains to include cheese types
def map_strains_to_cheese(row):
    strains = row['present_in_strains']
    return [cheese_map.get(s, 'Unknown') for s in strains]

# %%
# Look for peptidase genes
peptidase_genes = gpa[gpa['Annotation'].fillna('').str.contains('peptidase', case=False)]

# Identify strain columns
strain_cols = [col for col in gpa.columns if col.startswith('Lactobacillus')]

# Count how many strains each gene is present in
peptidase_genes['num_strains'] = peptidase_genes[strain_cols].notna().sum(axis=1)
# Out:
# <ipython-input-25-1dd4ce655b94>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   peptidase_genes['num_strains'] = peptidase_genes[strain_cols].notna().sum(axis=1)

# %%
# Classify as core or accessory
total_strains = len(strain_cols)
peptidase_genes['core_or_accessory'] = peptidase_genes['num_strains'].apply(
    lambda x: 'core' if x == total_strains else 'accessory'
)
# Out:
# <ipython-input-26-429be37b384c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   peptidase_genes['core_or_accessory'] = peptidase_genes['num_strains'].apply(

# %%
# Add list of strains where gene is present
peptidase_genes['present_in_strains'] = peptidase_genes[strain_cols].apply(
    lambda row: [strain for strain in strain_cols if pd.notna(row[strain])], axis=1
)

# Show selected columns
peptidase_summary = peptidase_genes[['Gene',
                                     'Annotation', 'num_strains',
                                     'core_or_accessory', 'present_in_strains']]


# Add cheese info
peptidase_summary['cheese_type_present_in'] = peptidase_summary.apply(map_strains_to_cheese, axis=1)
# Out:
# <ipython-input-27-28b032b047ab>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   peptidase_genes['present_in_strains'] = peptidase_genes[strain_cols].apply(
# <ipython-input-27-28b032b047ab>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   peptidase_summary['cheese_type_present_in'] = peptidase_summary.apply(map_strains_to_cheese, axis=1)

# %%
pd.set_option('max_colwidth', 50) # regulate columns width

peptidase_summary
# Out:
#             Gene                                    Annotation  num_strains  \
# 81    group_1276                         Neutral endopeptidase            9
# 109         pepC                              Aminopeptidase C            9
# 135          pip                        Proline iminopeptidase            9
# 263       spsB_1                           Signal peptidase IB            9
# 292         pepX                  Xaa-Pro dipeptidyl-peptidase            9
# 452       pepE_3                              Aminopeptidase E            9
# 478       spsB_2                           Signal peptidase IB            9
# 482         fpaP                        Proline iminopeptidase            9
# 555          map                   Methionine aminopeptidase 1            9
# 568       pepE_2                              Aminopeptidase E            9
# 637         pepQ                           Xaa-Pro dipeptidase            9
# 641       dacA_1      D-alanyl-D-alanine carboxypeptidase DacA            9
# 642      pepDA_3                                 Dipeptidase A            9
# 645         lspA                  Lipoprotein signal peptidase            9
# 654       pepO_3                         Neutral endopeptidase            9
# 685         ypdF                           Aminopeptidase YpdF            9
# 689       pepT_2                                   Peptidase T            9
# 718       pepT_1                                   Peptidase T            9
# 722         pepV                      Beta-Ala-Xaa dipeptidase            9
# 733         ysdC                  Putative aminopeptidase YsdC            9
# 736       pepO_1                         Neutral endopeptidase            9
# 790       pepD_2                                   Dipeptidase            9
# 826      pepDA_2                                 Dipeptidase A            9
# 953      pepDA_4                                 Dipeptidase A            9
# 974        pepF1                 Oligoendopeptidase F, plasmid            9
# 975         pppA                       Prepilin peptidase PppA            9
# 996         pepN                              Aminopeptidase N            9
# 1006         pcp             Pyrrolidone-carboxylate peptidase            9
# 1277      pepD_1                                   Dipeptidase            8
# 1278  group_1120                                 Dipeptidase A            8
# 1608      pepE_1                              Aminopeptidase E            6
# 1761      pepD_3                                   Dipeptidase            5
# 2779  group_1343                              Aminopeptidase C            1
# 3417        yfeW  Putative D-alanyl-D-alanine carboxypeptidase            1
# 3986  group_4001                                 Dipeptidase A            1
#
#      core_or_accessory                                 present_in_strains  \
# 81                core  [Lactobacillus_helveticus_CNRZ32, Lactobacillu...
# 109               core  [Lactobacillus_helveticus_CNRZ32, Lactobacillu...
# 135               core  [Lactobacillus_helveticus_CNRZ32, Lactobacillu...
# 263               core  [Lactobacillus_helveticus_CNRZ32, Lactobacillu...
# 292               core  [Lactobacillus_helveticus_CNRZ32, Lactobacillu...
# 452               core  [Lactobacillus_helveticus_CNRZ32, Lactobacillu...
# 478               core  [Lactobacillus_helveticus_CNRZ32, Lactobacillu...
# 482               core  [Lactobacillus_helveticus_CNRZ32, Lactobacillu...
# 555               core  [Lactobacillus_helveticus_CNRZ32, Lactobacillu...
# 568               core  [Lactobacillus_helveticus_CNRZ32, Lactobacillu...
# 637               core  [Lactobacillus_helveticus_CNRZ32, Lactobacillu...
# 641               core  [Lactobacillus_helveticus_CNRZ32, Lactobacillu...
# 642               core  [Lactobacillus_helveticus_CNRZ32, Lactobacillu...
# 645               core  [Lactobacillus_helveticus_CNRZ32, Lactobacillu...
# 654               core  [Lactobacillus_helveticus_CNRZ32, Lactobacillu...
# 685               core  [Lactobacillus_helveticus_CNRZ32, Lactobacillu...
# 689               core  [Lactobacillus_helveticus_CNRZ32, Lactobacillu...
# 718               core  [Lactobacillus_helveticus_CNRZ32, Lactobacillu...
# 722               core  [Lactobacillus_helveticus_CNRZ32, Lactobacillu...
# 733               core  [Lactobacillus_helveticus_CNRZ32, Lactobacillu...
# 736               core  [Lactobacillus_helveticus_CNRZ32, Lactobacillu...
# 790               core  [Lactobacillus_helveticus_CNRZ32, Lactobacillu...
# 826               core  [Lactobacillus_helveticus_CNRZ32, Lactobacillu...
# 953               core  [Lactobacillus_helveticus_CNRZ32, Lactobacillu...
# 974               core  [Lactobacillus_helveticus_CNRZ32, Lactobacillu...
# 975               core  [Lactobacillus_helveticus_CNRZ32, Lactobacillu...
# 996               core  [Lactobacillus_helveticus_CNRZ32, Lactobacillu...
# 1006              core  [Lactobacillus_helveticus_CNRZ32, Lactobacillu...
# 1277         accessory  [Lactobacillus_helveticus_CNRZ32, Lactobacillu...
# 1278         accessory  [Lactobacillus_helveticus_CNRZ32, Lactobacillu...
# 1608         accessory  [Lactobacillus_helveticus_H10, Lactobacillus_h...
# 1761         accessory  [Lactobacillus_helveticus_DPC_4571, Lactobacil...
# 2779         accessory                  [Lactobacillus_helveticus_CNRZ32]
# 3417         accessory                     [Lactobacillus_helveticus_H10]
# 3986         accessory                     [Lactobacillus_helveticus_H10]
#
#                                  cheese_type_present_in
# 81    [milk, cheese, dairy, cheese, milk, fermented ...
# 109   [milk, cheese, dairy, cheese, milk, fermented ...
# 135   [milk, cheese, dairy, cheese, milk, fermented ...
# 263   [milk, cheese, dairy, cheese, milk, fermented ...
# 292   [milk, cheese, dairy, cheese, milk, fermented ...
# 452   [milk, cheese, dairy, cheese, milk, fermented ...
# 478   [milk, cheese, dairy, cheese, milk, fermented ...
# 482   [milk, cheese, dairy, cheese, milk, fermented ...
# 555   [milk, cheese, dairy, cheese, milk, fermented ...
# 568   [milk, cheese, dairy, cheese, milk, fermented ...
# 637   [milk, cheese, dairy, cheese, milk, fermented ...
# 641   [milk, cheese, dairy, cheese, milk, fermented ...
# 642   [milk, cheese, dairy, cheese, milk, fermented ...
# 645   [milk, cheese, dairy, cheese, milk, fermented ...
# 654   [milk, cheese, dairy, cheese, milk, fermented ...
# 685   [milk, cheese, dairy, cheese, milk, fermented ...
# 689   [milk, cheese, dairy, cheese, milk, fermented ...
# 718   [milk, cheese, dairy, cheese, milk, fermented ...
# 722   [milk, cheese, dairy, cheese, milk, fermented ...
# 733   [milk, cheese, dairy, cheese, milk, fermented ...
# 736   [milk, cheese, dairy, cheese, milk, fermented ...
# 790   [milk, cheese, dairy, cheese, milk, fermented ...
# 826   [milk, cheese, dairy, cheese, milk, fermented ...
# 953   [milk, cheese, dairy, cheese, milk, fermented ...
# 974   [milk, cheese, dairy, cheese, milk, fermented ...
# 975   [milk, cheese, dairy, cheese, milk, fermented ...
# 996   [milk, cheese, dairy, cheese, milk, fermented ...
# 1006  [milk, cheese, dairy, cheese, milk, fermented ...
# 1277  [milk, cheese, dairy, cheese, milk, fermented ...
# 1278  [milk, cheese, dairy, cheese, swiss cheese, ch...
# 1608  [milk, fermented milk, swiss cheese, cheese, s...
# 1761  [dairy, cheese, swiss cheese, cheese, swiss ch...
# 2779                                     [milk, cheese]
# 3417                             [milk, fermented milk]
# 3986                             [milk, fermented milk]

# %% [markdown]
# # 4. Get genes that might be related to development of a cheese flavour and texture

# %%
# === 1. Filter flavor-related genes ===
flavor_keywords = [
    'aminotransferase', 'methionine', 'cystathionine', 'decarboxylase',
    'sulfur', 'aroma', 'lipase', 'esterase', 'ald', 'tnaA', 'cysK', 'metC', 'ilvE', 'tyrB'
]

flavor_genes = gpa[gpa['Annotation'].fillna('').str.contains('|'.join(flavor_keywords), case=False)]

# === 2. Create binary matrix ===
binary_matrix = flavor_genes[strain_cols].notna().astype(int)
binary_matrix.index = flavor_genes['Gene'] # Use gene ID as index

# === 3. Add cheese type labels to strains ===
strain_cheese_type = meta.set_index('short_name')['Cheese Type(s)'].fillna("Unknown")
column_colors = strain_cheese_type.loc[binary_matrix.columns]

# Convert to colors for heatmap (optional step)
cheese_palette = {
    c: color for c, color in zip(column_colors.unique(), sns.color_palette("Set2", len(column_colors.unique())))
}
column_colors_mapped = column_colors.map(cheese_palette)

# === 4. Plot heatmap ===
sns.clustermap(
    binary_matrix,
    figsize=(15, 10),
    cmap="Greens",
    col_colors=column_colors_mapped,
    yticklabels=True,
    xticklabels=True,
    cbar_kws={"label": "Gene Presence"}
)

plt.tight_layout()
plt.suptitle("Flavor & Texture Genes Presence Across Strains (Cheese Types Color-Coded)", y=1.02)
plt.show()

# %% [markdown]
# # 5. Get genes that are enriched in swiss cheese strains

# %%
# Intersect strains from both files
strain_cols = [col for col in gpa.columns if col in meta['short_name'].values]
# meta_filtered = meta[meta['short_name'].isin(strain_cols)]
cheese_map = dict(zip(meta['short_name'], meta['Cheese Type(s)'].fillna("Unknown")))

# %%
cheese_map
# Out:
# {'Lactobacillus_helveticus_DPC_4571': 'dairy, cheese',
#  'Lactobacillus_helveticus_H10': 'milk, fermented milk',
#  'Lactobacillus_helveticus_CNRZ32': 'milk, cheese',
#  'Lactobacillus_helveticus_TJA10': 'milk, dairy, fermented milk',
#  'Lactobacillus_helveticus_Lh21462': 'swiss cheese, cheese',
#  'Lactobacillus_helveticus_Lh21463': 'swiss cheese, cheese',
#  'Lactobacillus_helveticus_Lh11961': 'swiss cheese, cheese',
#  'Lactobacillus_helveticus_Lh11051': 'swiss cheese, cheese',
#  'Lactobacillus_helveticus_Lh21456': 'swiss cheese, cheese'}

# %%
# Identify Swiss cheese strains
swiss_strains = meta[meta['Cheese Type(s)'].str.contains("swiss", case=False, na=False)]['short_name'].values
swiss_matrix = gpa[swiss_strains].notna().astype(int)
non_swiss_strains = [s for s in strain_cols if s not in swiss_strains]
non_swiss_matrix = gpa[non_swiss_strains].notna().astype(int)

# %%
# Define swiss-enriched genes
# the gene is present in most (≥80%) of the swiss cheese strains
# the gene is absent in most (≤20%) of the other strains


swiss_enriched_idx = (swiss_matrix.sum(axis=1) >= int(0.8 * len(swiss_strains))) & \
                     (non_swiss_matrix.sum(axis=1) <= int(0.2 * len(non_swiss_strains)))

swiss_enriched_genes = gpa.loc[swiss_enriched_idx, 'Gene']
swiss_enriched_matrix = gpa.loc[swiss_enriched_idx, strain_cols].notna().astype(int)
swiss_enriched_matrix.index = gpa.loc[swiss_enriched_idx, 'Gene']

# Map cheese types to strains
strain_cheese_type = meta.set_index('short_name')['Cheese Type(s)'].fillna("Unknown")
column_colors = strain_cheese_type.loc[swiss_enriched_matrix.columns]

# Assign palette
cheese_palette = {
    c: color for c, color in zip(column_colors.unique(), sns.color_palette("Set2", len(column_colors.unique())))
}
column_colors_mapped = column_colors.map(cheese_palette)

# %%
# Plot heatmap
sns.clustermap(
    swiss_enriched_matrix,
    figsize=(10, 15),
    cmap="Blues",
    col_colors=column_colors_mapped,
    yticklabels=True,
    xticklabels=True,
    cbar_kws={"label": "Gene Presence"}
)
plt.tight_layout()
plt.suptitle("Swiss Cheese Enriched Genes Across Strains", y=1.02)
plt.show()

# %%
#### #### #### #### #### #### #### ####  #### #### ####
#### LET'S ADD FUNCTIONAL INFO FROM EGGNOME-MAPPER ######
#### #### #### #### #### #### #### ####  #### #### ####

# Merge with gene presence matrix
gene_labels = swiss_enriched_matrix.index.to_series().reset_index(drop=True).to_frame(name='Gene')
gene_labels = gene_labels.merge(eggnog[['Gene', 'COG_descr', 'Description']],
                                how='left', on='Gene')

gene_labels = gene_labels[~((gene_labels.Description.isna()) |\
                             (gene_labels.Description.str.contains('potential problem')) |\
                                (gene_labels.Description == "-") |\
                                    (gene_labels.Description == " "))]

swiss_enriched_matrix = swiss_enriched_matrix.loc[gene_labels.Gene]

# Update row labels in matrix with annotated descriptions (or fallback to gene name)
swiss_enriched_matrix.index = [
    f"{g} - {d}" if pd.notna(d) else g
    for g, d in zip(gene_labels['Gene'], gene_labels['COG_descr'])
]

# Replot heatmap with annotation-enriched row labels
sns.clustermap(
    swiss_enriched_matrix,
    figsize=(10, 12),
    cmap="Blues",
    col_colors=column_colors_mapped,
    yticklabels=True,
    xticklabels=True,
    cbar_kws={"label": "Gene Presence"}
)
plt.tight_layout()
plt.suptitle("Swiss Cheese Enriched Genes (with Annotation)", y=1.02)
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/matrix.py:1113: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   self._figure.tight_layout(**tight_params)
# <ipython-input-35-7345e39397a5>:33: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %% [markdown]
# # Questions

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import fcluster

# %% [markdown]
# ### 1. Cluster bacteria and examine grouping by niche

# %%
# Cut dendrogram into clusters
max_clusters = 4
clusters = fcluster(Z, t=max_clusters, criterion='maxclust')
cluster_df = pd.DataFrame({
    'strain': binary_matrix.columns,
    'cluster': clusters,
    'cheese_type': [cheese_colors[s] for s in binary_matrix.columns]
})

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=cluster_df, x='cluster', hue='cheese_type', palette=palette)
plt.title('Cluster Composition by Cheese Niche')
plt.xlabel('Cluster ID')
plt.ylabel('Number of Strains')
plt.legend(title='Cheese Type', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.savefig("cluster_composition.pdf", bbox_inches='tight', format='pdf')
plt.show()

# %%
# Identify DPC strain cluster
dpc_cluster = cluster_df.loc[cluster_df['strain'].str.contains('DPC'), 'cluster'].iloc[0]
print(f"DPC strain is in cluster {dpc_cluster}, which contains: \n",
      cluster_df[cluster_df['cluster'] == dpc_cluster]['cheese_type'].value_counts())
# Out:
# DPC strain is in cluster 2, which contains:
#  cheese_type
# swiss cheese, cheese    4
# dairy, cheese           1
# Name: count, dtype: int64

# %% [markdown]
# ### 2. H10-specific genes functional categories

# %%
h10_cogs = eggnog_h10['COG_category'].dropna().str.cat()
h10_cog_counts = Counter([c for c in h10_cogs if c in cog_descriptions])
cog_labels = [f"{c} ({cog_descriptions[c]})" for c in h10_cog_counts]
cog_vals = [h10_cog_counts[c] for c in h10_cog_counts]

# %%
plt.figure(figsize=(10, 6))
plt.bar(cog_labels, cog_vals)
plt.xticks(rotation=90)
plt.title('H10-unique Genes by COG Functional Category')
plt.ylabel('Number of Genes')
plt.tight_layout()
plt.savefig("h10_cog_barplot.pdf", bbox_inches='tight', format='pdf')
plt.show()

# %% [markdown]
# ### 3. Milk fermentation candidate genes in H10

# %%
display(milk_ferment_related)
# Out:
#                                  query_name Preferred_name  \
# 2761   c8b8aac069fa36cfcc7e4f9a83d2e35b_524           prtB
# 2784   c8b8aac069fa36cfcc7e4f9a83d2e35b_622              -
# 2807   c8b8aac069fa36cfcc7e4f9a83d2e35b_720           lacZ
# 2822   c8b8aac069fa36cfcc7e4f9a83d2e35b_752           potE
# 2931  c8b8aac069fa36cfcc7e4f9a83d2e35b_1144           steT
# 2932  c8b8aac069fa36cfcc7e4f9a83d2e35b_1149           prtP
# 3089  c8b8aac069fa36cfcc7e4f9a83d2e35b_1946              -
# 3139  c8b8aac069fa36cfcc7e4f9a83d2e35b_2118          pepD4
#
#                                Description COG_category    KEGG_ko  \
# 2761    Belongs to the peptidase S8 family            O  ko:K01361
# 2784            Peptidase family M1 domain            M          -
# 2807                   -beta-galactosidase            G  ko:K12308
# 2822                            Amino Acid            E          -
# 2931                            amino acid            E  ko:K03294
# 2932    Belongs to the peptidase S8 family            O  ko:K01361
# 3089  Peptidase propeptide and YPEB domain            S          -
# 3139                           Dipeptidase            E  ko:K08659
#
#           KEGG_Pathway                                                GOs
# 2761                 -                                                  -
# 2784                 -                                                  -
# 2807  ko00052,map00052                                                  -
# 2822                 -                                                  -
# 2931                 -  GO:0003333,GO:0003674,GO:0005215,GO:0005342,GO...
# 2932                 -                                                  -
# 3089                 -                                                  -
# 3139                 -                                                  -

# %% [markdown]
# ### 4. Peptidase distribution: core vs accessory

# %%
print(peptidase_summary['core_or_accessory'].value_counts())
# Out:
# core_or_accessory
# core         28
# accessory     7
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6, 4))
peptidase_summary['core_or_accessory'].value_counts().plot(kind='bar')
plt.title('Peptidase Genes: Core vs Accessory')
plt.ylabel('Count')
plt.tight_layout()
plt.savefig("peptidase_barplot.pdf", bbox_inches='tight', format='pdf')
plt.show()

# %% [markdown]
# ### 5. Flavor/texture enzymes distribution summary

# %%
flavor_binary = binary_matrix  # from earlier step for flavor_genes
flavor_counts = flavor_binary.sum(axis=1).sort_values(ascending=False)
flavor_summary = pd.DataFrame({'Gene': flavor_counts.index, 'presence_count': flavor_counts.values})
display(flavor_summary.head(10))
# Out:
#      Gene  presence_count
# 0  patB_2               9
# 1    adhE               9
# 2  patB_1               9
# 3    PSD2               9
# 4    metQ               9
# 5  dapX_2               9
# 6    galM               9
# 7    msrC               9
# 8     map               9
# 9    gdpP               9

# %% [markdown]
# ### 6. Swiss cheese enriched genes exploration

# %%
unique_swiss = swiss_enriched_genes[swiss_matrix.sum(axis=1) == len(swiss_strains)]
print(unique_swiss.tolist())
# Out:
# ['group_1249', 'group_1252', 'group_1884', 'group_3824', 'group_439', 'group_58', 'group_674', 'aroE', 'group_88', 'zosA']

# %%
swiss_annotations = eggnog[eggnog['Gene'].isin(swiss_enriched_genes)]
gene_func = swiss_annotations[['Gene', 'COG_category', 'COG_descr', 'Description']].drop_duplicates()
display(gene_func)
# Out:
#             Gene COG_category  \
# 3209   group_245            S
# 3210   group_246            S
# 3212   group_674            S
# 3214   group_175            T
# 3222  group_2805            -
# ...          ...          ...
# 3354  group_3824            L
# 3357      ycaM_6            E
# 3363  group_3861            L
# 3366      rsmF_2            J
# 3369     group_4            L
#
#                                               COG_descr  \
# 3209       S | Uncharacterised protein family (UPF0236)
# 3210       S | Uncharacterised protein family (UPF0236)
# 3212                                    S | SLAP domain
# 3214             T | phosphoserine phosphatase activity
# 3222                                              - | -
# ...                                                 ...
# 3354  L | An automated process has identified a pote...
# 3357                            E | Amino acid permease
# 3363  L | Transposase and inactivated derivatives, I...
# 3366                   J | NOL1 NOP2 sun family protein
# 3369                 L | transposase, IS605 OrfB family
#
#                                             Description
# 3209           Uncharacterised protein family (UPF0236)
# 3210           Uncharacterised protein family (UPF0236)
# 3212                                        SLAP domain
# 3214                 phosphoserine phosphatase activity
# 3222                                                  -
# ...                                                 ...
# 3354  An automated process has identified a potentia...
# 3357                                Amino acid permease
# 3363  Transposase and inactivated derivatives, IS30 ...
# 3366                       NOL1 NOP2 sun family protein
# 3369                     transposase, IS605 OrfB family
#
# [69 rows x 4 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('swiss_enriched_gene_functions.csv')

df['COG_descr'] = df['COG_descr'].replace('-', 'Unknown')

cog_counts = df['COG_descr'].value_counts().reset_index()
cog_counts.columns = ['COG_descr', 'Count']

plt.figure(figsize=(10, 6))
sns.barplot(data=cog_counts, x='COG_descr', y='Count', palette='viridis')
plt.title('Distribution of COG Categories in Swiss-Enriched Genes')
plt.xlabel('COG Category')
plt.ylabel('Number of Genes')
plt.xticks(rotation=90)
plt.savefig("swiss_heatmap.pdf", bbox_inches='tight', format='pdf')
plt.show()
# Out:
# <ipython-input-48-141f17ff8cf8>:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=cog_counts, x='COG_descr', y='Count', palette='viridis')

# %%
df = pd.read_csv('swiss_enriched_gene_functions.csv')

keywords = [
    'sugar', 'amino acid', 'gustatory', 'taste', 'receptor',
    'ion channel', 'chemosensory', 'sweet', 'bitter'
]

taste_rows = df[
    df['COG_descr'].str.contains('|'.join(keywords), case=False, na=False) |
    df['Description'].str.contains('|'.join(keywords), case=False, na=False)
]

display(taste_rows)
# Out:
#           Gene COG_category                          COG_descr  \
# 19  group_2817            E                     E | amino acid
# 24  group_2824            K  K | Putative sugar-binding domain
# 65      ycaM_6            E            E | Amino acid permease
#
#                       Description
# 19                     amino acid
# 24  Putative sugar-binding domain
# 65            Amino acid permease
